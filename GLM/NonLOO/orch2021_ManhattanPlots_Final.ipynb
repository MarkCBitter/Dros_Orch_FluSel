# %%
#Manhattan plots of orchard 2021 data
##Plotting all interval length/comparison glm results
##This plotting scheme is modified from functions writen by S. Greenblum and provided here - https://github.com/greensii/dros-adaptive-tracking

# %%
source("/home/users/mcbitter/OrchardProject/Code/config.R")
source("/home/users/mcbitter/OrchardProject/Code/helper_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/load_packages.R")
source("/home/users/mcbitter/OrchardProject/Code/plotting_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/workflow_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/general_cage_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/Orchard2021_Scripts/LOA/loa.orch2021.functions.R")
setwd('~/dpetrov/MarkB/Orchard2021Data/')

# %%
# 1 tpt intervals
setwd('~/dpetrov/MarkB/Orchard2021Data/09_ExpandingPhases/NonLOA/SigSites_Discrete/')
df.sig = read.csv('./df.sig.ExpandingPhases.Weekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))


#

# %%
df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->2', 'T2->3', 'T3->4', 'T4->5', 'T5->6', 'T6->7', 
                                                        'T7->8', 'T8->9', 'T9->10', 'T10->11', 'T11->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.1 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,5))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=12), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
p.1
ggsave('../../../Figures/ManhattanPlots/manhattan.1tpt.pdf', p.1, height = 14, width = 14)
# Out:
# plot without title

# %%
setwd('~/dpetrov/MarkB/Orchard2021Data/09_ExpandingPhases/NonLOA/SigSites_ContinuousGLM/')

# %%
# 2 Tpt intervals
df.sig = read.csv('./df.sig.ExpandingPhases.BiWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->3', 'T2->4', 'T3->5', 'T4->6', 'T5->7', 'T6->8', 
                                                        'T7->9', 'T8->10', 'T9->11', 'T10->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.2 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,5))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))

ggsave('../../Figures//ManhattanPlots/manhattan.2tpt.pdf', p.2, height = 14, width = 10)

# %%
# 3 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.TriWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->4', 'T2->5', 'T3->6', 'T4->7', 'T5->8', 'T6->9', 
                                                        'T7->10', 'T8->11', 'T9->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.3 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,9))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))

ggsave('../../Figures//ManhattanPlots/manhattan.3tpt.pdf', p.3, height = 14, width = 10)

# %%
# 4 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.TetraWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->5', 'T2->6', 'T3->7', 'T4->8', 'T5->9', 'T6->10', 
                                                        'T7->11', 'T8->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.4 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,12))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))

p.4
ggsave('../../Figures//ManhattanPlots/manhattan.4tpt.pdf', p.4, height = 12, width = 10)
# Out:
# plot without title

# %%
#5 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.PentaWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->6', 'T2->7', 'T3->8', 'T4->9', 'T5->10', 'T6->11', 
                                                        'T7->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.5 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,18))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
p.5
ggsave('../../Figures//ManhattanPlots/manhattan.5tpt.pdf', p.5, height = 14, width = 10)
# Out:
# plot without title

# %%
# 6 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.HexWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->7', 'T2->8', 'T3->9', 'T4->10', 'T5->11', 'T6->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.6 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,20))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
ggsave('../../Figures//ManhattanPlots/manhattan.6tpt.pdf', p.6, height = 14, width = 10)

# %%
ggsave('../../Figures//ManhattanPlots/manhattan.6tpt.pdf', p.6, height = 14, width = 10)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”

# %%
# 7 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.HeptWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->8', 'T2->9', 'T3->10', 'T4->11', 'T5->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.7 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,25))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))

# %%
p.7
# Out:
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggsave('../../Figures//ManhattanPlots/manhattan.7tpt.pdf', p.7, height = 14, width = 10)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”

# %%
# 8 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.OctWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->9', 'T2->10', 'T3->11', 'T4->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.8 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,25))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
p.8
# Out:
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggsave('../../../Figures/ManhattanPlots/manhattan.8tpt.pdf', p.8, height = 12, width = 10)
# Out:
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”

# %%
# 9 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.EnneaWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->10', 'T2->11', 'T3->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.9 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,25))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
p.9
# Out:
# Warning message:
# “Removed 4 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggsave('../../../Figures//ManhattanPlots/manhattan.9tpt.pdf', p.9, height = 10, width = 10)
# Out:
# Warning message:
# “Removed 4 rows containing missing values (`geom_point()`).”

# %%
# 10 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.DecWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->11', 'T2->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.10 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,30))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))

# %%
ggsave('../../../Figures/ManhattanPlots/manhattan.10tpt.pdf', p.10, height = 9, width = 10)
# Out:
# Warning message:
# “Removed 3 rows containing missing values (`geom_point()`).”

# %%
#Just spring to fall 
df.sig = read.csv('./df.sig.ExpandingPhases.DecWeekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->11', 'T2->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.StF = (df.sig %>% filter(compLabel == 'T1->11')) %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,25))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_blank(),strip.text.y = element_blank(),
          axis.text.y=element_text(size=25), axis.text.x=element_text(size=25),
         axis.title = element_text(size = 25)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
p.StF

# %%
ggsave('../../Figures/ManhattanPlots/manhattan.SpToFa.pdf', p.StF, height = 14, width = 15)
# Out:
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”

# %%
# 11 Tpt
df.sig = read.csv('./df.sig.ExpandingPhases.11Weekly.orch21.csv')
df.sig = df.sig %>% separate(comparison, into = c('ta', 'tb'), sep = '_' ) %>%
    mutate(comparison = paste0('T', ta, '->', tb)) %>%
    dplyr::select(-ta, -tb)
df.sig <- df.sig %>% mutate(sigLabel=as.factor(sigLevel),compLabel = as.factor(comparison))

df.sig$compLabel = factor(df.sig$compLabel, levels = c('T1->12'))
df.sig = df.sig %>% filter(abs(afShift) > 0.005)

p.11 = df.sig %>% ggplot(aes(x=pos/1000000))+ theme_minimal() + lims(y=c(0,30))  +
    facet_grid(compLabel ~ chrom,scales="free_x", switch="y") + 
    theme(legend.position = 'none',strip.text = element_text(size=20),strip.text.y = element_text(size=15),
          axis.text.y=element_text(size=15), axis.text.x=element_text(size=15),
         axis.title = element_text(size = 15)) +
    labs(x="Position (Mb)",y="-log10(FDR-corrected p-value)") +
    suppressWarnings(geom_point(aes(y=-log10(FDR),color=sigLabel),alpha=.8,size=1)) +
    scale_colour_manual(values = c('grey', 'orange', 'red'))
p.11
# Out:
# Warning message:
# “Removed 5 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggsave('../../../Figures//ManhattanPlots/manhattan.11tpt.pdf', p.11, height = 7, width = 10)
# Out:
# Warning message:
# “Removed 5 rows containing missing values (`geom_point()`).”

# %%
####
